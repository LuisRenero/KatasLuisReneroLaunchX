# %%
new_planet = ''
planets = []

# %%
while new_planet != 'done':
    if new_planet != '':
        planets.append(new_planet)
    new_planet = input("Ingresa un planeta para agregar a la lista")

# %%
print(planets)
# Out:
# ['pluto', 'Mercurio', 'Venus', 'Tierra']

# %%
for planet in planets:
    print(planet)
# Out:
# pluto
# Mercurio
# Venus
# Tierra
