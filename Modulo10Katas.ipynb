# %%
open("/path/to/mars.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 1' in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000000?line=0'>1</a> open("/path/to/mars.jpg")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/path/to/mars.jpg'

# %%
def main():
    open("/path/to/mars.jpg")

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 2' in <module>
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000001?line=1'>2</a>     open("/path/to/mars.jpg")
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000001?line=3'>4</a> if __name__ == '__main__':
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000001?line=4'>5</a>     main()
#
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 2' in main()
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000001?line=0'>1</a> def main():
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000001?line=1'>2</a>     open("/path/to/mars.jpg")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/path/to/mars.jpg'

# %%
def main():
    try:
        open("/path/to/mars.jpg")
    except FileNotFoundError:
        print("Couldn't find the file!")

if __name__ == '__main__':
    main()
# Out:
# Couldn't find the file!

# %%
def main():
    try:
        configuration = open('config.txt')
    except FileNotFoundError:
        print("Couldn't find the config.txt file!")

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 4' in <module>
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000005?line=4'>5</a>         print("Couldn't find the config.txt file!")
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000005?line=6'>7</a> if __name__ == '__main__':
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000005?line=7'>8</a>     main()
#
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 4' in main()
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000005?line=0'>1</a> def main():
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000005?line=1'>2</a>     try:
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000005?line=2'>3</a>         configuration = open('config.txt')
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000005?line=3'>4</a>     except FileNotFoundError:
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000005?line=4'>5</a>         print("Couldn't find the config.txt file!")
#
# PermissionError: [Errno 13] Permission denied: 'config.txt'

# %%
def main():
    try:
        configuration = open('config.txt')
    except FileNotFoundError:
        print("Couldn't find the config.txt file!")
    except PermissionError:
        print("Found config.txt but it has not permission, couldn't read it")

main()
# Out:
# Found config.txt but it has not permission, couldn't read it

# %%
def main():
    try:
        configuration = open('config.txt')
    except FileNotFoundError as err:
        print("got a problem trying to read the file:", err)

main()
# Out:
# got a problem trying to read the file: [Errno 2] No such file or directory: 'config.txt'

# %%
def water_left(astronauts, water_left, days_left):
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    return f"Total water left after {days_left} days is: {total_water_left} liters"

water_left(5, 100, 2)
# Out:
# 'Total water left after 2 days is: -10 liters'

# %%
def water_left(astronauts, water_left, days_left):
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    if total_water_left < 0:
        raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
    return f"Total water left after {days_left} days is: {total_water_left} liters"

water_left(5, 100, 2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 8' in <module>
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=5'>6</a>         raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=6'>7</a>     return f"Total water left after {days_left} days is: {total_water_left} liters"
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=8'>9</a> water_left(5, 100, 2)
#
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 8' in water_left(astronauts, water_left, days_left)
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=3'>4</a> total_water_left = water_left - total_usage
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=4'>5</a> if total_water_left < 0:
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=5'>6</a>     raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=6'>7</a> return f"Total water left after {days_left} days is: {total_water_left} liters"
#
# RuntimeError: There is not enough water for 5 astronauts after 2 days!

# %%
water_left(5, 100, 2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 9' in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000008?line=0'>1</a> water_left(5, 100, 2)
#
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 8' in water_left(astronauts, water_left, days_left)
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=3'>4</a> total_water_left = water_left - total_usage
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=4'>5</a> if total_water_left < 0:
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=5'>6</a>     raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=6'>7</a> return f"Total water left after {days_left} days is: {total_water_left} liters"
#
# RuntimeError: There is not enough water for 5 astronauts after 2 days!

# %%
def water_alert():
    try:
        water_left(5, 100, None)
    except RuntimeError as err:
        print(err)

water_alert()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 10' in <module>
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000009?line=3'>4</a>     except RuntimeError as err:
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000009?line=4'>5</a>         print(err)
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000009?line=6'>7</a> water_alert()
#
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 10' in water_alert()
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000009?line=0'>1</a> def water_alert():
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000009?line=1'>2</a>     try:
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000009?line=2'>3</a>         water_left("3", "200", None)
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000009?line=3'>4</a>     except RuntimeError as err:
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000009?line=4'>5</a>         print(err)
#
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 8' in water_left(astronauts, water_left, days_left)
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=0'>1</a> def water_left(astronauts, water_left, days_left):
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=1'>2</a>     daily_usage = astronauts * 11
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=2'>3</a>     total_usage = daily_usage * days_left
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=3'>4</a>     total_water_left = water_left - total_usage
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=4'>5</a>     if total_water_left < 0:
#
# TypeError: can't multiply sequence by non-int of type 'NoneType'

# %%
def water_alert():
    try:
        water_left("3", "200", None)
    except RuntimeError as err:
        print(err)

water_alert()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 11' in <module>
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000010?line=3'>4</a>     except RuntimeError as err:
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000010?line=4'>5</a>         print(err)
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000010?line=6'>7</a> water_alert()
#
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 11' in water_alert()
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000010?line=0'>1</a> def water_alert():
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000010?line=1'>2</a>     try:
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000010?line=2'>3</a>         water_left("3", "200", None)
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000010?line=3'>4</a>     except RuntimeError as err:
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000010?line=4'>5</a>         print(err)
#
# d:\sch\KatasLuisReneroLaunchX\Modulo10Katas.ipynb Cell 8' in water_left(astronauts, water_left, days_left)
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=0'>1</a> def water_left(astronauts, water_left, days_left):
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=1'>2</a>     daily_usage = astronauts * 11
# ----> <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=2'>3</a>     total_usage = daily_usage * days_left
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=3'>4</a>     total_water_left = water_left - total_usage
#       <a href='vscode-notebook-cell:/d%3A/sch/KatasLuisReneroLaunchX/Modulo10Katas.ipynb#ch0000007?line=4'>5</a>     if total_water_left < 0:
#
# TypeError: can't multiply sequence by non-int of type 'NoneType'
