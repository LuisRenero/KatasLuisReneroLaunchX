# %% [markdown]
# # Ejercicio 1:

# %%
planet = {
    'name': 'Mars',
    'moons': 2
}

# %%
print(f"The planet {planet['name']} has {planet['moons']} moons")
# Out:
# The planet Mars has 2 moons

# %%
planet['circunferencia(km)'] = {'polar': 6752, 'equatorial':6792}

# %%
print(f'{planet["name"]} has a polar circunfemference of {planet["circunferencia(km)"]["polar"]}')
# Out:
# Mars has a polar circunfemference of 6752

# %% [markdown]
# # Ejercicio 2:

# %%
planet_moons = {
    'mercury': 0,
    'venus': 0,
    'earth': 1,
    'mars': 2,
    'jupiter': 79,
    'saturn': 82,
    'uranus': 27,
    'neptune': 14,
    'pluto': 5,
    'haumea': 2,
    'makemake': 1,
    'eris': 1
}

# %%
print(planet_moons.values())
# Out:
# dict_values([0, 0, 1, 2, 79, 82, 27, 14, 5, 2, 1, 1])

# %%
moons_count = 0
for moons in planet_moons.values():
    moons_count = moons_count + moons

print(moons_count)
# Out:
# 214
