# %% [markdown]
# # Lógica condicional
# ### Advertencia de asteroide

# %%
# Añadir el código necesario para crear una variable que guarde la velocidad del asteroide.
# Escribe una expresión de prueba para calcular si necesita una advertencia.
# Agregue las instrucciones que se ejecutarán si la expresión de prueba es true o false.
velocidad_asteroide = 49
if velocidad_asteroide > 25:
    print("¡Advertencia! Asteroide aproximándose a una velocidad peligrosa")
else:
    print("Asteroide acercandose, pero no representa un peligro")
# Out:
# ¡Advertencia! Asteroide aproximándose a una velocidad peligrosa

# %% [markdown]
# ### Advertencia para avistar un asteroide

# %%
# Agrega el código para crear una variable para un asteroide que viaja a 19 km/s
# Escribe varias expresiones de prueba para determinar si puedes ver el rayo de luz desde la tierra
# Agrega las instrucciones que se ejecutarán si las expresiones de prueba son True o False

velocidad_asteroide = 19
if velocidad_asteroide > 20:
    print("¡Mira arriba! Hay un asteroide muy visible")
elif velocidad_asteroide == 20:
    print("¡Mira arriba! Hay un asteroide visible")
else:
    print("Hay un asteroide pero no es visible")
# Out:
# Hay un asteroide pero no es visible

# %% [markdown]
# ### Advertencia según velocidad y tamaño
#
# Prueba 1

# %%
# Agrega el código para crear nuevas variables para la velocidad y el tamaño del asteroide
# Para probar el código, prueba con varias velocidades y tamaños
# Escribe varias expresiones de prueba o combinaciones de expresiones de prueba para determinar qué mensaje se debe enviar a Tierra.

velocidad_asteroide2 = 20
tamano_asteroide = 49

if velocidad_asteroide2 > 25 and tamano_asteroide > 25:
    print("¡Final inminente! Se aproxima una asteroide que causará mucho daño") 
elif velocidad_asteroide2 > 25 or tamano_asteroide > 25:
    print("¡Advertencia! se apróxima un asteroide daño considerable")
elif velocidad_asteroide2 > 20:
    print("Mira arriba, hay un asteroide visible")
else:
    print("Nada de que hablar")
# Out:
# ¡Advertencia! se apróxima un asteroide daño considerable

# %% [markdown]
# Prueba 2

# %%
velocidad_asteroide2 = 25
tamano_asteroide = 25

if velocidad_asteroide2 > 25 and tamano_asteroide > 25:
    print("¡Final inminente! Se aproxima una asteroide que causará mucho daño") 
elif velocidad_asteroide2 > 25 or tamano_asteroide > 25:
    print("¡Advertencia! se apróxima un asteroide daño considerable")
elif velocidad_asteroide2 > 20:
    print("Mira arriba, hay un asteroide visible")
else:
    print("Nada de que hablar")
# Out:
# Mira arriba, hay un asteroide visible

# %% [markdown]
# Prueba 3

# %%
velocidad_asteroide2 = 26
tamano_asteroide = 26

if velocidad_asteroide2 > 25 and tamano_asteroide > 25:
    print("¡Final inminente! Se aproxima una asteroide que causará mucho daño") 
elif velocidad_asteroide2 > 25 or tamano_asteroide > 25:
    print("¡Advertencia! se apróxima un asteroide daño considerable")
elif velocidad_asteroide2 > 20:
    print("Mira arriba, hay un asteroide visible")
else:
    print("Nada de que hablar")
# Out:
# ¡Final inminente! Se aproxima una asteroide que causará mucho daño

# %% [markdown]
# Prueba 4

# %%
velocidad_asteroide2 = 1
tamano_asteroide = 1

if velocidad_asteroide2 > 25 and tamano_asteroide > 25:
    print("¡Final inminente! Se aproxima una asteroide que causará mucho daño") 
elif velocidad_asteroide2 > 25 or tamano_asteroide > 25:
    print("¡Advertencia! se apróxima un asteroide daño considerable")
elif velocidad_asteroide2 > 20:
    print("Mira arriba, hay un asteroide visible")
else:
    print("Nada de que hablar")
# Out:
# Nada de que hablar
